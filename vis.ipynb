# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.DataFrame(car_crashes)
sns.scatterplot(data=df, x= "speeding", y= "alcohol")
plt.title("relationship b/w two varibles")
plt.xlabel("speeding")
plt.ylabel("alcohal")
# Out:
# Text(0, 0.5, 'alcohal')

# %%
import matpoltlib .pyplot as plt
x,y=[1,2,3,4],[1,4,9,16]
plt.plto(x,y)
plt.ylabel(squares)[4,5,7,8]
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 import matpoltlib .pyplot as plt
#       2 x,y=[1,2,3,4],[1,4,9,16]
#       3 plt.plto(x,y)
#
# ModuleNotFoundError: No module named 'matpoltlib'

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df=pd.dateframe(car_crashes)
sns.scatterplot
